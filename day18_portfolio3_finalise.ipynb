# %% [markdown]
# <a href="https://colab.research.google.com/github/ayyanarh1/tamil-nadu-school-flood-risk/blob/main/day18_portfolio3_finalise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Setup
# !pip install fpdf2 -q
from fpdf import FPDF
import pandas as pd

print('✅ Day 18 ready!')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.1/327.1 kB 19.5 MB/s eta 0:00:00
# ✅ Day 18 ready!

# %%
# Phase 3 summary
print('=== PORTFOLIO PROJECT 3 COMPLETE ===')
print()
print('Phase 3 — Streamlit Dashboard (Days 14-18)')
print()
print('What you built:')
print('  Day 14 — Streamlit app deployed on Streamlit Cloud')
print('  Day 15 — Enhanced with charts + scenario toggle')
print('  Day 16 — 570 school Giga dataset integrated')
print('  Day 17 — Full 580-school dashboard live')
print('  Day 18 — Portfolio polished + LinkedIn post')
print()
print('Live app URL:')
print('  https://tamil-nadu-school-flood-risk-ewc2sj7fhrvvtkwlpw5jzf.streamlit.app/')
print()
print('Dashboard features:')
print('  ✅ 580 schools — Tamil Nadu + Mozambique')
print('  ✅ 4 interactive tabs')
print('  ✅ 4 Plotly charts')
print('  ✅ District + risk + connectivity filters')
print('  ✅ School profile with mini map')
print('  ✅ CSV download button')
print('  ✅ 2050 scenario toggle')
print('  ✅ Methodology expander')
print()
print('Portfolio projects complete:')
print('  ✅ Project 1 — Tamil Nadu flood risk (Days 1-7)')
print('  ✅ Project 2 — Multi-country risk modeling (Days 8-13)')
print('  ✅ Project 3 — Live Streamlit dashboard (Days 14-18)')
print('  ⏳ Project 4 — Giga Spatial contribution (Days 22-25)')
# Out:
# === PORTFOLIO PROJECT 3 COMPLETE ===
#
# Phase 3 — Streamlit Dashboard (Days 14-18)
#
# What you built:
#   Day 14 — Streamlit app deployed on Streamlit Cloud
#   Day 15 — Enhanced with charts + scenario toggle
#   Day 16 — 570 school Giga dataset integrated
#   Day 17 — Full 580-school dashboard live
#   Day 18 — Portfolio polished + LinkedIn post
#
# Live app URL:
#   https://tamil-nadu-school-flood-risk-ewc2sj7fhrvvtkwlpw5jzf.streamlit.app/
#
# Dashboard features:
#   ✅ 580 schools — Tamil Nadu + Mozambique
#   ✅ 4 interactive tabs
#   ✅ 4 Plotly charts
#   ✅ District + risk + connectivity filters
#   ✅ School profile with mini map
#   ✅ CSV download button
#   ✅ 2050 scenario toggle
#   ✅ Methodology expander
#
# Portfolio projects complete:
#   ✅ Project 1 — Tamil Nadu flood risk (Days 1-7)
#   ✅ Project 2 — Multi-country risk modeling (Days 8-13)
#   ✅ Project 3 — Live Streamlit dashboard (Days 14-18)
#   ⏳ Project 4 — Giga Spatial contribution (Days 22-25)

# %%
# General LinkedIn post
linkedin_post = """
🛰️ Built a satellite-based school flood risk dashboard from scratch!

Over the past 18 days I combined 6 geospatial data sources to assess
flood and cyclone risk for 580 schools across two countries.

🌊 Data sources used:
- Sentinel-1 SAR satellite imagery
- JRC Global Surface Water (37 years of flood history)
- Global Flood Database (913 major flood events)
- ERA5 climate reanalysis data
- IBTrACS cyclone track data
- IPCC AR6 SSP 2050 climate projections

📊 Key findings:
- 88 of 580 schools at CRITICAL flood risk
- Coastal schools with no connectivity face compound risk
- Same pattern confirmed across both countries
- 5 schools escalate to CRITICAL by 2050 under worst case scenario

🔧 Full technical stack:
Google Earth Engine | Python | GeoPandas | Rasterio
Folium | Streamlit | ERA5 API | OSMnx | Plotly
Contextily | IBTrACS | fpdf2 | openpyxl

🌐 Live dashboard:
https://tamil-nadu-school-flood-risk-ewc2sj7fhrvvtkwlpw5jzf.streamlit.app/

💻 Full code + 17 notebooks on GitHub:
https://github.com/ayyanarh1/tamil-nadu-school-flood-risk

This project demonstrates how open satellite data and climate datasets
can be combined to identify schools most at risk from flooding and
cyclones — and how connectivity gaps compound that risk.

Happy to connect with others working in geospatial data science,
climate risk or education technology!

#GIS #RemoteSensing #ClimateRisk #Python #GoogleEarthEngine
#Streamlit #OpenSource #Geospatial #FloodRisk #ClimateChange
#DataScience #SatelliteImagery #OpenData
"""

print(linkedin_post)

with open('linkedin_post.txt', 'w') as f:
    f.write(linkedin_post)
print('✅ LinkedIn post saved!')
# Out:
# 🛰️ Built a satellite-based school flood risk dashboard from scratch!
#
# Over the past 18 days I combined 6 geospatial data sources to assess
# flood and cyclone risk for 580 schools across two countries.
#
# 🌊 Data sources used:
# - Sentinel-1 SAR satellite imagery
# - JRC Global Surface Water (37 years of flood history)
# - Global Flood Database (913 major flood events)
# - ERA5 climate reanalysis data
# - IBTrACS cyclone track data
# - IPCC AR6 SSP 2050 climate projections
#
# 📊 Key findings:
# - 88 of 580 schools at CRITICAL flood risk
# - Coastal schools with no connectivity face compound risk
# - Same pattern confirmed across both countries
# - 5 schools escalate to CRITICAL by 2050 under worst case scenario
#
# 🔧 Full technical stack:
# Google Earth Engine | Python | GeoPandas | Rasterio
# Folium | Streamlit | ERA5 API | OSMnx | Plotly
# Contextily | IBTrACS | fpdf2 | openpyxl
#
# 🌐 Live dashboard:
# https://tamil-nadu-school-flood-risk-ewc2sj7fhrvvtkwlpw5jzf.streamlit.app/
#
# ...
